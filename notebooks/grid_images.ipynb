# %%
root_dir = '/home/rampfire/ERA__V_1/vision_meets_nlp/data/'

# %%
from torchvision.datasets import CIFAR10
from torchvision.transforms import transforms
import numpy

# %%
        simple_transforms = transforms.Compose([
                                      #  transforms.Resize((28, 28)),
                                      #  transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                       transforms.ToTensor(),
                                      #  transforms.Normalize((0.1307,), (0.3081,)) # The mean and std have to be sequences (e.g., tuples), therefore you should add a comma after the values. 
                                       # Note the difference between (0.1307) and (0.1307,)
                                       ])

# %%
        cifar_trainset = CIFAR10(root_dir, train=True, download=True, transform=simple_transforms)

        imgs = [item[0] for item in cifar_trainset]
# Out:
# Files already downloaded and verified

# %%
cifar_trainset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /home/rampfire/ERA__V_1/vision_meets_nlp/data/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %%
for c,i in cifar_trainset.class_to_idx:
    print(c,i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 for c,i in cifar_trainset.class_to_idx:
#       2     print(c,i)
#
# ValueError: too many values to unpack (expected 2)

# %%
sample_dict = {}
idx_to_key = {}

# %%
for key in cifar_trainset.class_to_idx:
    print(key, '->', cifar_trainset.class_to_idx[key])
    sample_dict[key] = []
    idx_to_key[cifar_trainset.class_to_idx[key]] = key
# Out:
# airplane -> 0
# automobile -> 1
# bird -> 2
# cat -> 3
# deer -> 4
# dog -> 5
# frog -> 6
# horse -> 7
# ship -> 8
# truck -> 9

# %%
sample_dict
# Out:
# {'airplane': [],
#  'automobile': [],
#  'bird': [],
#  'cat': [],
#  'deer': [],
#  'dog': [],
#  'frog': [],
#  'horse': [],
#  'ship': [],
#  'truck': []}

# %%
for i,target in enumerate(cifar_trainset.targets):
    print(i,target,idx_to_key[target])
    sample_dict[idx_to_key[target]].append({"index" : i,"img" : imgs[i]})
# Out:
# 0 6 frog
# 1 9 truck
# 2 9 truck
# 3 4 deer
# 4 1 automobile
# 5 1 automobile
# 6 2 bird
# 7 7 horse
# 8 8 ship
# 9 3 cat
# 10 4 deer
# 11 7 horse
# 12 7 horse
# 13 2 bird
# 14 9 truck
# 15 9 truck
# 16 9 truck
# 17 3 cat
# 18 2 bird
# 19 6 frog
# 20 4 deer
# 21 3 cat
# 22 6 frog
# 23 6 frog
# 24 2 bird
# 25 6 frog
# 26 3 cat
# 27 5 dog
# 28 4 deer
# 29 0 airplane
# 30 0 airplane
# 31 9 truck
# 32 1 automobile
# 33 3 cat
# 34 4 deer
# 35 0 airplane
# 36 3 cat
# 37 7 horse
# 38 3 cat
# 39 3 cat
# 40 5 dog
# 41 2 bird
# 42 2 bird
# 43 7 horse
# 44 1 automobile
# 45 1 automobile
# 46 1 automobile
# 47 2 bird
# 48 2 bird
# 49 0 airplane
# 50 9 truck
# 51 5 dog
# 52 7 horse
# 53 9 truck
# 54 2 bird
# 55 2 bird
# 56 5 dog
# 57 2 bird
# 58 4 deer
# 59 3 cat
# 60 1 automobile
# 61 1 automobile
# 62 8 ship
# 63 2 bird
# 64 1 automobile
# 65 1 automobile
# 66 4 deer
# 67 9 truck
# 68 7 horse
# 69 8 ship
# 70 5 dog
# 71 9 truck
# 72 6 frog
# 73 7 horse
# 74 3 cat
# 75 1 automobile
# 76 9 truck
# ...

# %%
idx_to_key
# Out:
# {0: 'airplane',
#  1: 'automobile',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %%
len(sample_dict["airplane"])
# Out:
# 5000

# %%
import torchvision

# %%
grid_img = torchvision.utils.make_grid(imgs[:10], nrow=5)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(grid_img.permute(1, 2, 0))

# %%
type(imgs)
# Out:
# list

# %%
for img in sample_dict[key]:
    print(img)
    break
# Out:
# {'index': 29, 'img': tensor([[[0.7922, 0.7922, 0.8000,  ..., 0.8118, 0.8039, 0.7961],
#          [0.8078, 0.8078, 0.8118,  ..., 0.8235, 0.8157, 0.8078],
#          [0.8235, 0.8275, 0.8314,  ..., 0.8392, 0.8314, 0.8235],
#          ...,
#          [0.8549, 0.8235, 0.7608,  ..., 0.9529, 0.9569, 0.9529],
#          [0.8588, 0.8510, 0.8471,  ..., 0.9451, 0.9451, 0.9451],
#          [0.8510, 0.8471, 0.8510,  ..., 0.9373, 0.9373, 0.9412]],
#
#         [[0.8000, 0.8000, 0.8078,  ..., 0.8157, 0.8078, 0.8000],
#          [0.8157, 0.8157, 0.8196,  ..., 0.8275, 0.8196, 0.8118],
#          [0.8314, 0.8353, 0.8392,  ..., 0.8392, 0.8353, 0.8275],
#          ...,
#          [0.8510, 0.8196, 0.7608,  ..., 0.9490, 0.9490, 0.9529],
#          [0.8549, 0.8471, 0.8471,  ..., 0.9412, 0.9412, 0.9412],
#          [0.8471, 0.8431, 0.8471,  ..., 0.9333, 0.9333, 0.9333]],
#
#         [[0.7804, 0.7804, 0.7882,  ..., 0.7843, 0.7804, 0.7765],
#          [0.7961, 0.7961, 0.8000,  ..., 0.8039, 0.7961, 0.7882],
# ...

# %%
images_to_display = []
for key in sample_dict:
    for img in sample_dict[key][:10]:
        images_to_display.append(img["img"])

# %%
len(images_to_display)
# Out:
# 100

# %%
images_to_display[0].shape
# Out:
# torch.Size([3, 32, 32])

# %%
import os
os.getcwd()
# Out:
# '/home/rampfire/ERA__V_1/vision_meets_nlp/notebooks'

# %%
os.listdir("../fonts")
# Out:
# ['Arial.ttf']

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw 

img = Image.new("RGB", (32, 32), (255, 255, 255))
draw = ImageDraw.Draw(img)
font = ImageFont.truetype("../fonts/Arial.ttf", 10)
# draw.text((x, y),"Sample Text",(r,g,b))
draw.text((0, 0),"Sample Text",(0,0,0),font=font)

# %%
plt.imshow(simple_transforms(img).permute(1, 2, 0))

# %%
font.getsize("Sample")
# Out:
# /tmp/ipykernel_811/2293645735.py:1: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   font.getsize("Sample")
# (34, 12)

# %%
img.size[0]
# Out:
# 32

# %%
font.getsize(text)
# Out:
# /tmp/ipykernel_811/3499405815.py:1: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   font.getsize(text)
# (34, 12)

# %%
fontsize = 1
text = "Sample"
while font.getsize(text)[0] < img.size[0]:
    fontsize +=1
# Out:
# /tmp/ipykernel_811/2852971031.py:3: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   while font.getsize(text)[0] < img.size[0]:

# %%
fontsize
# Out:
# 1

# %%
number_of_images = 20
device = "cpu"
misclassified_imgs = []
correct_classified_imgs = []
with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        pred = output.argmax(dim=1, keepdim=True)
        is_correct = pred.eq(target.view_as(pred))
        misclassified_inds = (is_correct==0).nonzero()[:,0]
        correct_classified_inds = (is_correct==1).nonzero()[:,0]
        for mis_ind in misclassified_inds:
            if len(misclassified_imgs) < number_of_images:
                misclassified_imgs.append({
                    "target": target[mis_ind].cpu().numpy(),
                    "pred": pred[mis_ind][0].cpu().numpy(),
                    "img": data[mis_ind].cpu().numpy()[0]
                })
            else:
                break
        for mis_ind in correct_classified_inds:
            if len(correct_classified_imgs) < number_of_images:
                correct_classified_imgs.append({
                    "target": target[mis_ind].cpu().numpy(),
                    "pred": pred[mis_ind][0].cpu().numpy(),
                    "img": data[mis_ind].cpu().numpy()[0]
                })
            else:
                break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for data,target in datamodule.data_test:
#       2     break
#
# NameError: name 'datamodule' is not defined
